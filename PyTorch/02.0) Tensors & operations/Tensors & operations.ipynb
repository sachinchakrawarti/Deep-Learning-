# %% [markdown]
# ## Tensors & Operations in PyTorch

# %% [markdown]
# Tensors are the core data structure in PyTorch, similar to Numpy arrays but with GPU acceleration and automatic differentiation support

# %% [markdown]
# 1) Creating Tensors

# %%
import torch
